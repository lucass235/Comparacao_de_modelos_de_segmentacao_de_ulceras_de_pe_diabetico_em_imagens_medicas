# %%
import os
from PIL import Image, ImageFilter

# %%
def augment_images(input_folder, output_folder, augmentations, suffix="_augmented"):
    """
    Aplica augmentações em imagens de uma pasta e salva em outra pasta com nomes concatenados.

    Args:
        input_folder (str): Caminho da pasta de entrada com as imagens originais.
        output_folder (str): Caminho da pasta de saída para salvar as imagens augmentadas.
        augmentations (list): Lista de funções de augmentação a serem aplicadas.
        suffix (str): Sufixo a ser adicionado ao nome do arquivo.
    """
    # Cria a pasta de saída, se não existir
    os.makedirs(output_folder, exist_ok=True)

    # Itera por todas as imagens na pasta de entrada
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            input_path = os.path.join(input_folder, filename)

            # Extrai o nome base e a extensão do arquivo
            name, ext = os.path.splitext(filename)
            output_filename = f"{name}{suffix}{ext}"
            output_path = os.path.join(output_folder, output_filename)

            # Abre a imagem
            with Image.open(input_path) as img:
                # Aplica cada augmentação
                for augmentation in augmentations:
                    img = augmentation(img)

                # Salva a imagem augmentada com o nome concatenado
                img.save(output_path)
                print(f"Imagem salva: {output_path}")

# %%
# Função de augmentação: converte para grayscale
def to_grayscale(image):
    return image.convert("L")

# Função de augmentação: rotaciona a imagem
def rotate_image(image, angle=45):
    return image.rotate(angle)

# Função de augmentação: aplica blur (desfoque)
def apply_blur(image):
    return image.filter(ImageFilter.BLUR)

# Função de augmentação: espelha horizontalmente
def flip_horizontal(image):
    return image.transpose(Image.FLIP_LEFT_RIGHT)

# %%
# Exemplo de uso
input_folder = "../woundSegmentation/data/Foot Ulcer Segmentation Challenge/test/labels"  # Pasta com as imagens originais
output_folder = "../data/aumentation/test/labels"  # Pasta para salvar as imagens augmentadas

# Lista de augmentações a serem aplicadas
augmentations = [
    # to_grayscale,          # Converte para grayscale
    lambda img: rotate_image(img, angle=45),  # Rotaciona em 45 graus
    # apply_blur,            # Aplica blur
    flip_horizontal        # Espelha horizontalmente
]

augment_images(input_folder, output_folder, augmentations)
# Out:
# Imagem salva: ../data/aumentation/test/labels\0001_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0002_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0003_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0004_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0005_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0006_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0007_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0008_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0009_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0010_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0025_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0030_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0033_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0046_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0047_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0057_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0058_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0062_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0068_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0078_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0079_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0082_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0085_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0089_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0096_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0107_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0108_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0122_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0124_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0126_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0128_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0133_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0134_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0136_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0143_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0146_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0164_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0177_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0180_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0190_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0192_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0201_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0203_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0208_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0211_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0213_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0217_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0233_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0235_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0245_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0251_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0256_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0259_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0262_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0276_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0278_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0284_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0289_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0291_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0300_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0301_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0303_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0322_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0326_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0334_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0337_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0339_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0341_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0349_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0355_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0356_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0363_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0365_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0369_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0375_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0376_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0382_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0390_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0398_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0405_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0407_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0412_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0416_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0417_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0429_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0437_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0438_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0439_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0447_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0450_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0451_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0456_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0466_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0470_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0475_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0483_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0485_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0494_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0496_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0503_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0504_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0511_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0516_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0517_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0525_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0528_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0533_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0541_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0543_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0545_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0548_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0549_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0557_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0559_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0565_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0566_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0571_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0577_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0580_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0582_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0588_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0591_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0603_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0604_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0607_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0612_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0615_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0616_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0627_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0638_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0642_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0644_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0647_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0651_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0652_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0657_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0674_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0679_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0682_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0706_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0712_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0715_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0717_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0721_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0728_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0729_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0730_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0738_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0745_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0757_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0763_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0781_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0796_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0798_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0802_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0806_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0809_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0813_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0816_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0820_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0824_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0830_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0833_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0834_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0835_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0842_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0847_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0849_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0865_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0867_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0869_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0874_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0880_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0881_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0887_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0900_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0901_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0904_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0905_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0906_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0922_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0937_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0940_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0946_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0947_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0948_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0949_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0954_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0955_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0958_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0961_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0964_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0971_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0973_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0974_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0976_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0979_augmented.png
# Imagem salva: ../data/aumentation/test/labels\0985_augmented.png
# Imagem salva: ../data/aumentation/test/labels\1003_augmented.png
# Imagem salva: ../data/aumentation/test/labels\1009_augmented.png
