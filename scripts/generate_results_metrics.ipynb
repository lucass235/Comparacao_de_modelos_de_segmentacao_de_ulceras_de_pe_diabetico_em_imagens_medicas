# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv('../data/results_metrics_models.csv')

# %%
df
# Out:
#        model  epoch  precision  recall    dice    loss
# 0   FuSegNet    150     0.9990  0.9783  0.9817  0.0007
# 1        FCN    150     0.9756  0.9547  0.9606  0.0016
# 2      U-Net    150     0.9731  0.9515  0.9581  0.0017
# 3     SegNet    150     0.9386  0.9065  0.9200  0.0032
# 4  MobileNet    150     0.8985  0.8425  0.8662  0.0061

# %%
# remover coluna epoch
df.drop('epoch', axis=1, inplace=True)
df
# Out:
#        model  precision  recall    dice    loss
# 0   FuSegNet     0.9990  0.9783  0.9817  0.0007
# 1        FCN     0.9756  0.9547  0.9606  0.0016
# 2      U-Net     0.9731  0.9515  0.9581  0.0017
# 3     SegNet     0.9386  0.9065  0.9200  0.0032
# 4  MobileNet     0.8985  0.8425  0.8662  0.0061

# %%
# Defina as cores para as linhas do gráfico
colors = ['b', 'g', 'r', 'c', 'm']

# Crie um gráfico de linha para cada modelo
plt.figure(figsize=(10, 8))
for i, row in df.iterrows():
    plt.plot(df.columns[1:], row[1:], label=row['model'], color=colors[i])

# Adicione rótulos e legenda
plt.xlabel('Métricas')
plt.ylabel('Valores')
plt.title('Desempenho dos Modelos')
plt.legend()
plt.savefig('../data/imgs/results_metrics_models.png')
# Mostre o gráfico
plt.show()
